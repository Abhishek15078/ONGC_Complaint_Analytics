# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(
    data=df,
    x="Resolution_Speed"
)

plt.show()

# %%
df["Resolution_Speed"].value_counts()
# Out:
# Resolution_Speed
# Slow          1054
# Medium         436
# Unresolved     307
# Fast           203
# Name: count, dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['Ticket_No', 'Title', 'Description', 'Category', 'Priority', 'Department', 'Status', 'Resolution_Time_Hours', 'Arising_Date', 'Closing_Date', 'Sentiment_Label', 'Is_Resolved', 'SLA_Status', 'Month', 'Year', 'Quarter', 'Weekday', 'Resolution_Speed']

# %%
print(df["Resolution_Speed"].head())
# Out:
# 0      Slow
# 1      Slow
# 2      Slow
# 3    Medium
# 4      Fast
# Name: Resolution_Speed, dtype: str

# %%
def speed_bucket(hours):

    if hours == 0:
        return "Unresolved"

    elif hours <= 24:
        return "Fast"

    elif hours <= 72:
        return "Medium"

    else:
        return "Slow"


df["Resolution_Speed"] = df["Resolution_Time_Hours"].apply(speed_bucket)

# %%
sns.heatmap(
    pd.crosstab(
        df["Priority"],
        df["Sentiment_Label"]
    ),
    annot=True
)
# Out:
# <Axes: xlabel='Sentiment_Label', ylabel='Priority'>

# %%
pd.crosstab(
    df["Priority"],
    df["Sentiment_Label"]
)
# Out:
# Sentiment_Label  Frustrated  Neutral  Satisfied  Urgent
# Priority
# Critical                 40       32         35      25
# High                    171      190        158     177
# Low                     102      131        108      89
# Medium                  196      184        181     181

# %%
sns.countplot(
    data=df,
    x="Sentiment_Label"
)
# Out:
# <Axes: xlabel='Sentiment_Label', ylabel='count'>

# %%
df["Sentiment_Label"].value_counts()
# Out:
# Sentiment_Label
# Neutral       537
# Frustrated    509
# Satisfied     482
# Urgent        472
# Name: count, dtype: int64

# %%
sns.countplot(
    data=df,
    x="SLA_Status"
)
# Out:
# <Axes: xlabel='SLA_Status', ylabel='count'>

# %%
df["SLA_Status"].value_counts()
# Out:
# SLA_Status
# Breached      1054
# Within SLA     946
# Name: count, dtype: int64

# %%
sns.histplot(
    df["Resolution_Time_Hours"]
)
# Out:
# <Axes: xlabel='Resolution_Time_Hours', ylabel='Count'>

# %%
df["Resolution_Time_Hours"].describe()
# Out:
# count    2000.000000
# mean       80.449500
# std        61.762406
# min         0.000000
# 25%        23.000000
# 50%        78.500000
# 75%       128.250000
# max       239.000000
# Name: Resolution_Time_Hours, dtype: float64

# %%
plt.pie(
    df["Status"].value_counts(),
    labels=df["Status"].value_counts().index
)
# Out:
# ([<matplotlib.patches.Wedge at 0x1dbb7847a10>,
# ...
#  [Text(-0.5879498643396472, 0.9296854075562285, 'Closed'),
#   Text(0.08975003593399365, -1.0963324911037924, 'Resolved'),
#   Text(0.8649171450083839, -0.6796457402724939, 'In Progress'),
#   Text(1.0814752525240976, -0.20102556598089538, 'Pending')])

# %%
df["Status"].value_counts()
# Out:
# Status
# Closed         1359
# Resolved        334
# In Progress     190
# Pending         117
# Name: count, dtype: int64

# %%
sns.countplot(
    data=df,
    y="Category"
)
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
df["Category"].value_counts()
# Out:
# Category
# Incident                 609
# Request                  421
# Problem                  315
# Issue                    216
# Change                   155
# Software Installation     67
# Tape RW                   53
# Data Transfer             43
# Other                     37
# Project Creation          35
# Backup Restore            17
# User CUDA                 16
# Project Backup            16
# Name: count, dtype: int64

# %%
dept.plot(kind="bar")
# Out:
# <Axes: xlabel='Department'>

# %%
dept = (
    df["Department"]
    .value_counts()
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(
    data=df,
    x="Priority"
)

plt.show()

# %%
df["Priority"].value_counts()
# Out:
# Priority
# Medium      742
# High        696
# Low         430
# Critical    132
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Ticket_No              2000 non-null   str
#  1   Title                  1802 non-null   str
#  2   Description            2000 non-null   str
#  3   Category               2000 non-null   str
#  4   Priority               2000 non-null   str
#  5   Department             2000 non-null   str
#  6   Status                 2000 non-null   str
#  7   Resolution_Time_Hours  2000 non-null   int64
#  8   Arising_Date           2000 non-null   datetime64[us]
#  9   Closing_Date           1693 non-null   datetime64[us]
#  10  Sentiment_Label        2000 non-null   str
#  11  Is_Resolved            2000 non-null   bool
#  12  SLA_Status             2000 non-null   str
#  13  Month                  2000 non-null   str
#  14  Year                   2000 non-null   int64
# ...

# %%
df.shape
# Out:
# (2000, 17)

# %%
from pathlib import Path

for f in Path(".").rglob("*.xlsx"):
    print(f)

# %%
df = pd.read_excel(
    "../data/cleaned/cleaned_complaints.xlsx"
)

# %%
import os

print(os.listdir())
# Out:
# ['EDA.ipynb']

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\BIT\OneDrive\Desktop\ONGC_Complaint_Analytics\notebooks

# %%
import os

print(os.listdir())
# Out:
# ['EDA.ipynb']

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\BIT\OneDrive\Desktop\ONGC_Complaint_Analytics\notebooks
